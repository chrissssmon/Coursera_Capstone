# %% [markdown]
# # Capstone Project - The Battle of the Neighborhoods
# ### Applied Data Science Capstone by IBM/Coursera
# ### Christopher Lawrence

# %% [markdown]
# ***

# %% [markdown]
# ## Data Analysis for New Coffee Shop Locations in Anne Arundel County Maryland

# %% [markdown]
# ## Overview

# %% [markdown]
# For the Capstone project, I chose a scenario in which a large, national coffee chain is searching for new locations in which to open new coffee shops.  For the area, I chose to explore the region in which I currently live, Anne Arundel County Maryland.  This region is located in the suburbs between Baltimore Maryland and Washington D.C.  This area has a large metropolitan population with many coffee shops throughout the area.  I will use the Foursquare data API to establish the current coffee shop environment in Anne Arundel County in conjunction with other data sets from the Maryland and Anne Arundel Maryland County open data set web portals.

# %% [markdown]
# ***

# %% [markdown]
# ## Introduction and Background: Business Problem <a name="introduction"></a>

# %% [markdown]
# This section will present a brief description of the problem/question to be explored and a discussion of the background of the scenario presented in this Capstone.
#
# As stated in the overview section, this Capstone will present the problem of searching for an 'ideal' location to expand a new coffee shop store somewhere in the county of Anne Arundel Maryland.  Anne Arundel Maryland is a large, suburban county in the state of Maryland located between the cities of Baltimore Maryland and Washington D.C.  The problem/scenario presented in this Capstone will center around defining the properties of an 'ideal' location given the Foursquare API dataset information for existing coffee shops throughout the Anne Arundel county area.
#
# After exploring the various attributes of the existing coffee shop data in the Foursquare database (in conjunction with a systematic partitioning of Anne Arundel county via county open data sets (discussed in the data section), the business problem of where to locate a new coffee shop will become further defined.  In this scenario, the company wishes to expand its current number of coffee shops in the Anne Arundel county area, but also wants to maximize its business opportunities by avoiding areas of the county that are saturated in existing coffee shops and other establishments that cut into the coffee shop business.

# %% [markdown]
# ***

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# Import Libraries:

# %%
import pandas as pd
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# Get the datasets:

# %% [markdown]
# For now, Anne Arundel County will be partitioned by zip code.  So I will obtain the zip code dataset for Anne Arundel County from the official County open data web portal at https://opendata.aacounty.org/datasets/zip-codes

# %%
# importing the zip code .csv file

aa_zip_codes = pd.read_csv('https://opendata.arcgis.com/datasets/899d24a210094af38a6ebe83c53c760f_7.csv', header=0)

# %%
type(aa_zip_codes)
# Out:
# pandas.core.frame.DataFrame

# %%
aa_zip_codes.head()
# Out:
#    OBJECTID_1  OBJECTID    ZIP         PO_NAME STATE       CITY_NAME  \
# 0           1         1  21060     Glen Burnie    MD     Glen Burnie
# 1           2         2  20779  Tracys Landing    MD  Tracys Landing
# 2           3         3  20764      Shady Side    MD      Shady Side
# 3           4         4  20714     North Beach    MD     North Beach
# 4           5         5  21054       Gambrills    MD       Gambrills
#
#   CITY_CODE     Shape_Leng   ShapeSTArea  ShapeSTLength
# 0       GBE  135020.538278  3.792775e+08  135093.770581
# 1        TL   80203.800969  2.147892e+08   80203.800969
# 2        SS   53026.041572  1.580106e+08   53026.041572
# 3        NB   23465.940290  2.862809e+07   23465.940290
# 4        GM  245374.096713  4.930268e+08  248669.482468

# %%
aa_zip_codes.shape
# Out:
# (49, 10)

# %%
aa_zip_codes.dtypes
# Out:
# OBJECTID_1         int64
# OBJECTID           int64
# ZIP                int64
# PO_NAME           object
# STATE             object
# CITY_NAME         object
# CITY_CODE         object
# Shape_Leng       float64
# ShapeSTArea      float64
# ShapeSTLength    float64
# dtype: object

# %% [markdown]
# There are 49 zip code areas in Anne Arundel County. The dataset contains extra column data that can be removed, keeping only OBJECTID, ZIP, and PO_NAME.  There are no missing values or other issues for the remaining columns.

# %%
aa_zip_codes = aa_zip_codes.drop(['OBJECTID_1','STATE','PO_NAME','CITY_CODE', 'Shape_Leng','ShapeSTArea','ShapeSTLength'], axis=1)

# %%
aa_zip_codes.head()
# Out:
#    OBJECTID    ZIP       CITY_NAME
# 0         1  21060     Glen Burnie
# 1         2  20779  Tracys Landing
# 2         3  20764      Shady Side
# 3         4  20714     North Beach
# 4         5  21054       Gambrills

# %% [markdown]
# I need to find the latitude and longitude for each of the 49 zip code areas in Anne Arundel County:

# %% [markdown]
# I needed another dataset that linked zip codes and their corresponding lat/long geocoordinates.  I utilized a gazetteer file from the Census.gov web portal:

# %%
gen_zip_codes = pd.read_csv('2019_Gaz_zcta_national.csv', header=0)

# %%
gen_zip_codes.head()
# Out:
#    GEOID     ALAND  AWATER  ALAND_SQMI  AWATER_SQMI   INTPTLAT  INTPTLONG
# 0  20701   3429311    6563       1.324        0.003  39.125563 -76.785436
# 1  20705  41126879  259327      15.879        0.100  39.049423 -76.900362
# 2  20706  26786677  128248      10.342        0.050  38.965880 -76.851092
# 3  20707  28854743  466154      11.141        0.180  39.099170 -76.879786
# 4  20708  36138186  784564      13.953        0.303  39.048173 -76.824036

# %%
gen_zip_codes.shape
# Out:
# (219, 7)

# %%
gen_zip_codes = gen_zip_codes.drop(['ALAND','AWATER','ALAND_SQMI','AWATER_SQMI'], axis=1)

# %%
gen_zip_codes.rename(columns = {'GEOID':'ZIP'}, inplace = True)

# %%
gen_zip_codes.head()
# Out:
#      ZIP   INTPTLAT  INTPTLONG
# 0  20701  39.125563 -76.785436
# 1  20705  39.049423 -76.900362
# 2  20706  38.965880 -76.851092
# 3  20707  39.099170 -76.879786
# 4  20708  39.048173 -76.824036

# %%
gen_zip_codes.shape
# Out:
# (219, 3)

# %% [markdown]
# Now merge the two tables on zip code:

# %%
aa_zip_codes_2 = pd.merge(gen_zip_codes, aa_zip_codes, on='ZIP')
aa_zip_codes_2.head()
# Out:
#      ZIP   INTPTLAT  INTPTLONG  OBJECTID           CITY_NAME
# 0  20701  39.125563 -76.785436         9  Annapolis Junction
# 1  20701  39.125563 -76.785436        29          Fort Meade
# 2  20711  38.801059 -76.645107        12             Lothian
# 3  20714  38.722457 -76.532813         4         North Beach
# 4  20724  39.101077 -76.804003         6              Laurel

# %%
aa_zip_codes_2.shape
# Out:
# (49, 5)

# %%
aa_zip_codes_2.dtypes
# Out:
# ZIP            int64
# INTPTLAT     float64
# INTPTLONG    float64
# OBJECTID       int64
# CITY_NAME     object
# dtype: object

# %% [markdown]
# Let's plot a generic map of Anne Arundel County Maryland:

# %%
# use geopy library to get lat/long of Anne Arundel County

address = 'Anne Arundel, MD'

geolocator = Nominatim(user_agent="aa_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Anne Arundel are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Anne Arundel are 38.9722583, -76.573454.

# %%
aa_zip_codes_2.columns
# Out:
# Index(['ZIP', 'INTPTLAT', 'INTPTLONG', 'OBJECTID', 'CITY_NAME'], dtype='object')

# %%
# create map of Anne Arundel using latitude and longitude values
map_aaCounty = folium.Map(location=[latitude, longitude], zoom_start=10)
map_aaCounty
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# add markers to map
for lat, lng, city, zip_code in zip(aa_zip_codes_2['INTPTLAT'], aa_zip_codes_2['INTPTLONG'], aa_zip_codes_2['CITY_NAME'], aa_zip_codes_2['ZIP']):
    label = '{}, {}'.format(city, zip_code)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_aaCounty)

# %%
map_aaCounty
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Obtain coffee shop location data from Foursquare API database:

# %% [markdown]
# Define Foursquare credentials and version:

# %%
CLIENT_ID = 'SSVL0O4BQ4ERACH2R31MZCT1ZKL4YDIOHP4WJWKI0ET5WBHM' # your Foursquare ID
CLIENT_SECRET = 'Z52JPQVDEZH2TPNOKFU43JXMSRHVRCTVEVVIFYKG1XFEHGW2' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: SSVL0O4BQ4ERACH2R31MZCT1ZKL4YDIOHP4WJWKI0ET5WBHM
# CLIENT_SECRET:Z52JPQVDEZH2TPNOKFU43JXMSRHVRCTVEVVIFYKG1XFEHGW2

# %%
# function adapted from Project in week 3 to find nearby venues of a lat/long area--changed to bring back coffee shops only.

LIMIT = 10000 # limit of number of venues returned by Foursquare API

def getNearbyCoffeeShops(names, latitudes, longitudes, radius=10000):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %% [markdown]
# Run the function to get coffee shops for each zip code zone.

# %%
aa_venues = getNearbyCoffeeShops(names=aa_zip_codes_2['CITY_NAME'],
                                   latitudes=aa_zip_codes_2['INTPTLAT'],
                                   longitudes=aa_zip_codes_2['INTPTLONG']
                                  )
# Out:
# Annapolis Junction
# Fort Meade
# Lothian
# North Beach
# Laurel
# Fort Meade
# Churchton
# Owings
# Deale
# Dunkirk
# Fort Meade
# Fort Meade
# Friendship
# Shady Side
# Galesville
# Harwood
# West River
# Tracys Landing
# Fort Meade
# Jessup
# Arnold
# Crownsville
# Davidsonville
# Edgewater
# Gambrills
# Gibson Island
# Glen Burnie
# Glen Burnie
# Hanover
# Harmans
# Linthicum Heights
# Millersville
# Odenton
# Crofton
# Pasadena
# Riva
# Severn
# Severna Park
# Brooklyn
# Curtis Bay
# BWI Airport
# Annapolis
# Annapolis
# Naval Academy
# Annapolis
# Annapolis
# Annapolis
# Annapolis
# Annapolis

# %%
print(aa_venues.shape)
aa_venues
# Out:
# (4465, 7)
#             Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0     Annapolis Junction              39.125563              -76.785436
# 1     Annapolis Junction              39.125563              -76.785436
# 2     Annapolis Junction              39.125563              -76.785436
# 3     Annapolis Junction              39.125563              -76.785436
# 4     Annapolis Junction              39.125563              -76.785436
# 5     Annapolis Junction              39.125563              -76.785436
# 6     Annapolis Junction              39.125563              -76.785436
# 7     Annapolis Junction              39.125563              -76.785436
# 8     Annapolis Junction              39.125563              -76.785436
# 9     Annapolis Junction              39.125563              -76.785436
# 10    Annapolis Junction              39.125563              -76.785436
# 11    Annapolis Junction              39.125563              -76.785436
# 12    Annapolis Junction              39.125563              -76.785436
# 13    Annapolis Junction              39.125563              -76.785436
# 14    Annapolis Junction              39.125563              -76.785436
# 15    Annapolis Junction              39.125563              -76.785436
# 4268       -76.526236                              Gourmet Shop
# 4269       -76.546818                     Portuguese Restaurant
# 4270       -76.552215                        Salon / Barbershop
# 4271       -76.542971                       American Restaurant
# 4272       -76.536786                          Sushi Restaurant
# 4273       -76.505336                          Sushi Restaurant
# 4274       -76.536976                      Fast Food Restaurant
# 4275       -76.540671                       American Restaurant
# 4276       -76.540348                                 BBQ Joint
# 4277       -76.545761                                Nail Salon
# 4278       -76.531900                           Motorcycle Shop
# 4279       -76.539724                             Grocery Store
# 4280       -76.556389                                 Pet Store
# 4281       -76.547275                      Fast Food Restaurant
# 4282       -76.511741                                    Lounge
# 4283       -76.536555                         French Restaurant
# 4284       -76.542608                            Farmers Market
# 4285       -76.544475                       American Restaurant
# 4286       -76.539185                             Deli / Bodega
# 4287       -76.536859                 Latin American Restaurant
# 4288       -76.584432                     General Entertainment
# 4289       -76.545958                             Shopping Mall
# 4290       -76.619959                                      Café
# 4291       -76.544970                        Mexican Restaurant
# 4292       -76.511818                                Restaurant
# 4293       -76.546385                            Breakfast Spot
# 4294       -76.503006                                      Café
# 4295       -76.532526                         Convenience Store
# 4296       -76.546679                                       Spa
# 4297       -76.545446                               Coffee Shop
# 4298       -76.544740                                 Bookstore
# 4299       -76.584234                     General Entertainment
# 4300       -76.555399                                       Gym
# 4301       -76.507115                                   Stadium
# 4302       -76.555205                            Breakfast Spot
# 4303       -76.582372                                   Theater
# 4304       -76.502655                                Bagel Shop
# 4305       -76.546808                        Mexican Restaurant
# 4306       -76.523980                                Comic Shop
# 4307       -76.550651                     Vietnamese Restaurant
# 4308       -76.541627                       American Restaurant
# 4309       -76.546660                              Liquor Store
# 4310       -76.543490                       Arts & Crafts Store
# 4311       -76.546248                                 BBQ Joint
# 4312       -76.545297                          Video Game Store
# 4313       -76.555111                          Asian Restaurant
# 4314       -76.550058                                       Pub
# 4315       -76.549118                                Donut Shop
# 4316       -76.566024                       American Restaurant
# 4317       -76.546523                            Ice Cream Shop
# 4318       -76.510530                           Thai Restaurant
# 4319       -76.500731                                       Bar
# 4320       -76.490862                            Ice Cream Shop
# 4321       -76.546358                                Steakhouse
# 4322       -76.555250                   North Indian Restaurant
# 4323       -76.603487                              Liquor Store
# 4324       -76.547039                        Mexican Restaurant
# 4325       -76.512513                               Coffee Shop
# 4326       -76.486636                           Harbor / Marina
# 4327       -76.503377                            Breakfast Spot
# 4328       -76.537222                        Italian Restaurant
# 4329       -76.490299                                 Gastropub
# 4330       -76.487243                   Comfort Food Restaurant
# 4331       -76.493588                                       Pub
# 4332       -76.494603                                       Bar
# 4333       -76.491042                                Taco Place
# 4334       -76.488065                            History Museum
# 4335       -76.540332                             Shopping Mall
# 4336       -76.490541                         French Restaurant
# 4337       -76.575472                       American Restaurant
# 4338       -76.489898                       American Restaurant
# 4339       -76.495336                          Sushi Restaurant
# 4340       -76.494333                               Music Venue
# 4341       -76.488608                              Dessert Shop
# 4342       -76.499560                           Thai Restaurant
# 4343       -76.543517                            Cosmetics Shop
# 4344       -76.489936                             Deli / Bodega
# 4345       -76.583880                                      Park
# 4346       -76.495158                               Coffee Shop
# 4347       -76.584577                                       Pub
# 4348       -76.547897                               Coffee Shop
# 4349       -76.490770                                       Bar
# 4350       -76.555573                                       Gym
# 4351       -76.548892                              Liquor Store
# 4352       -76.539245                    Furniture / Home Store
# 4353       -76.503690                                     Hotel
# 4354       -76.545779                            Sandwich Place
# 4355       -76.518475                    Thrift / Vintage Store
# 4356       -76.482527                        Seafood Restaurant
# 4357       -76.484407                                    Bakery
# 4358       -76.569472                                     Trail
# 4359       -76.552053                           Warehouse Store
# 4360       -76.489844                                 Irish Pub
# 4361       -76.545145                      Gym / Fitness Center
# 4362       -76.544769                               Pizza Place
# 4363       -76.483940                        Seafood Restaurant
# 4364       -76.582655                        Chinese Restaurant
# 4365       -76.458187                        Seafood Restaurant
# 4366       -76.469399                          Department Store
# 4367       -76.439096                                      Café
# 4368       -76.470580                                 BBQ Joint
# 4369       -76.438022                                     Beach
# 4370       -76.439701                            Ice Cream Shop
# 4371       -76.439141                        Mexican Restaurant
# 4372       -76.486636                           Harbor / Marina
# 4373       -76.487243                   Comfort Food Restaurant
# 4374       -76.490862                            Ice Cream Shop
# 4375       -76.503006                                      Café
# 4376       -76.488065                            History Museum
# 4377       -76.482527                        Seafood Restaurant
# 4378       -76.488608                              Dessert Shop
# 4379       -76.490299                                 Gastropub
# 4380       -76.489898                       American Restaurant
# 4381       -76.490541                         French Restaurant
# 4382       -76.491042                                Taco Place
# 4383       -76.399097                                     Beach
# 4384       -76.505336                          Sushi Restaurant
# 4385       -76.484407                                    Bakery
# 4386       -76.483940                        Seafood Restaurant
# 4387       -76.489936                             Deli / Bodega
# 4388       -76.480265                                       Pub
# 4389       -76.481587                                Steakhouse
# 4390       -76.493588                                       Pub
# 4391       -76.502655                                Bagel Shop
# 4392       -76.480323                        Chinese Restaurant
# 4393       -76.398197                                     Beach
# 4394       -76.494603                                       Bar
# 4395       -76.482265                                Steakhouse
# 4396       -76.507115                                   Stadium
# 4397       -76.490770                                       Bar
# 4398       -76.494333                               Music Venue
# 4399       -76.486215                             Hot Dog Joint
# 4400       -76.495336                          Sushi Restaurant
# 4401       -76.488524                                  Wine Bar
# 4402       -76.480320                                    Market
# 4403       -76.489844                                 Irish Pub
# 4404       -76.500731                                       Bar
# 4405       -76.480614                       American Restaurant
# 4406       -76.495158                               Coffee Shop
# 4407       -76.511818                                Restaurant
# 4408       -76.490776                                       Bar
# 4409       -76.499560                           Thai Restaurant
# 4410       -76.481793                       American Restaurant
# 4411       -76.486353                                 BBQ Joint
# 4412       -76.456209                         Convenience Store
# 4413       -76.489984                            Sandwich Place
# 4414       -76.503377                            Breakfast Spot
# 4415       -76.480186                        Italian Restaurant
# 4416       -76.486591                                       Bar
# 4417       -76.489994                                Steakhouse
# 4418       -76.460670                       American Restaurant
# 4419       -76.429121                                   Theater
# 4420       -76.511741                                    Lounge
# 4421       -76.446670                                      Park
# 4422       -76.439326                                       Bar
# 4423       -76.476256                                    Museum
# 4424       -76.479629                       American Restaurant
# 4425       -76.486467                            Ice Cream Shop
# 4426       -76.368027                                       Bay
# 4427       -76.510530                           Thai Restaurant
# 4428       -76.487023                       American Restaurant
# 4429       -76.484461                                      Park
# 4430       -76.491685                                      Café
# 4431       -76.424510                                      Café
# 4432       -76.492676                                  Wine Bar
# 4433       -76.487386                                       Pub
# 4434       -76.503690                                     Hotel
# 4435       -76.486975                               Pizza Place
# 4436       -76.495480                                     Trail
# 4437       -76.512513                               Coffee Shop
# 4438       -76.526236                              Gourmet Shop
# 4439       -76.540039                             Grocery Store
# 4440       -76.536786                          Sushi Restaurant
# 4441       -76.536976                      Fast Food Restaurant
# 4442       -76.439579                             Grocery Store
# 4443       -76.531900                           Motorcycle Shop
# 4444       -76.503351                        Italian Restaurant
# 4445       -76.488531                               Coffee Shop
# 4446       -76.523980                                Comic Shop
# 4447       -76.492087                                 BBQ Joint
# 4448       -76.536859                 Latin American Restaurant
# 4449       -76.485728                               Social Club
# 4450       -76.540671                       American Restaurant
# 4451       -76.539724                             Grocery Store
# 4452       -76.540348                                 BBQ Joint
# 4453       -76.542608                            Farmers Market
# 4454       -76.539185                             Deli / Bodega
# 4455       -76.546818                     Portuguese Restaurant
# 4456       -76.542971                       American Restaurant
# 4457       -76.483188                                 Gift Shop
# 4458       -76.490430                        Mexican Restaurant
# 4459       -76.532526                         Convenience Store
# 4460       -76.499698                   New American Restaurant
# 4461       -76.518475                    Thrift / Vintage Store
# 4462       -76.545446                               Coffee Shop
# 4463       -76.544970                        Mexican Restaurant
# 4464       -76.484663                       American Restaurant

# %% [markdown]
# The Foursquare dataset returned data that contains two ways to say coffee shop, 'Coffee Shop' and 'Café', so I need to get both and merge into one dataframe.

# %% [markdown]
# Create a dataframe with the venue equal to 'Café'

# %%
aa_coffee_shops_1 = aa_venues[aa_venues['Venue Category'] == ('Café')]

# %%
aa_coffee_shops_1.head()
# Out:
#            Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 36   Annapolis Junction              39.125563              -76.785436
# 136          Fort Meade              39.125563              -76.785436
# 374              Laurel              39.101077              -76.804003
# 474          Fort Meade              39.101077              -76.804003
# 840          Fort Meade              39.107783              -76.747196
#
#                     Venue  Venue Latitude  Venue Longitude Venue Category
# 36   more than java cafe'       39.105322       -76.846451           Café
# 136  more than java cafe'       39.105322       -76.846451           Café
# 374  more than java cafe'       39.105322       -76.846451           Café
# 474  more than java cafe'       39.105322       -76.846451           Café
# 840  more than java cafe'       39.105322       -76.846451           Café

# %%
aa_coffee_shops_1.shape
# Out:
# (49, 7)

# %% [markdown]
# Now create a dataset with the venue equal to 'Coffee Shop'

# %%
aa_coffee_shops_2 = aa_venues[aa_venues['Venue Category'] == ('Coffee Shop')]

# %%
aa_coffee_shops_2.head()
# Out:
#           Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 34  Annapolis Junction              39.125563              -76.785436
# 38  Annapolis Junction              39.125563              -76.785436
# 62  Annapolis Junction              39.125563              -76.785436
# 70  Annapolis Junction              39.125563              -76.785436
# 84  Annapolis Junction              39.125563              -76.785436
#
#               Venue  Venue Latitude  Venue Longitude Venue Category
# 34        Starbucks       39.153211       -76.728363    Coffee Shop
# 38  Sip at C Street       39.106160       -76.845092    Coffee Shop
# 62        Starbucks       39.097870       -76.808211    Coffee Shop
# 70        Starbucks       39.156534       -76.724411    Coffee Shop
# 84        Starbucks       39.154524       -76.742366    Coffee Shop

# %%
aa_coffee_shops_2.shape
# Out:
# (135, 7)

# %% [markdown]
# Now concatenate the two coffee dataframes into one new complete coffee dataframe:

# %%
frames = [aa_coffee_shops_1, aa_coffee_shops_2]

# %%
aa_coffee_shops = pd.concat(frames)

# %%
aa_coffee_shops.head()
# Out:
#            Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 36   Annapolis Junction              39.125563              -76.785436
# 136          Fort Meade              39.125563              -76.785436
# 374              Laurel              39.101077              -76.804003
# 474          Fort Meade              39.101077              -76.804003
# 840          Fort Meade              39.107783              -76.747196
#
#                     Venue  Venue Latitude  Venue Longitude Venue Category
# 36   more than java cafe'       39.105322       -76.846451           Café
# 136  more than java cafe'       39.105322       -76.846451           Café
# 374  more than java cafe'       39.105322       -76.846451           Café
# 474  more than java cafe'       39.105322       -76.846451           Café
# 840  more than java cafe'       39.105322       -76.846451           Café

# %%
aa_coffee_shops.shape
# Out:
# (184, 7)

# %%
aa_coffee_shops.to_csv('aa_coffee_shops_final.csv')

# %% [markdown]
# Now map the coffee shops on the Anne Arundel County map to see the distribution:

# %%
# create map of Anne Arundel using latitude and longitude values
map_aaCounty = folium.Map(location=[latitude, longitude], zoom_start=10)

# %%
# add markers to map
for lat, lng, shop_name, neighborhood in zip(aa_coffee_shops['Venue Latitude'], aa_coffee_shops['Venue Longitude'], aa_coffee_shops['Venue'], aa_coffee_shops['Neighborhood']):
    label = '{}, {}'.format(shop_name, neighborhood)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_aaCounty)

# %%
map_aaCounty
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Now, I'll try clustering the coffee shop locations into several discreet clusters/areas to see if a regional pattern of dense/available areas emerge.  I'll begin with 7 clusters.

# %%
aa_coffee_shops.head()
# Out:
#            Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 36   Annapolis Junction              39.125563              -76.785436
# 136          Fort Meade              39.125563              -76.785436
# 374              Laurel              39.101077              -76.804003
# 474          Fort Meade              39.101077              -76.804003
# 840          Fort Meade              39.107783              -76.747196
#
#                     Venue  Venue Latitude  Venue Longitude Venue Category
# 36   more than java cafe'       39.105322       -76.846451           Café
# 136  more than java cafe'       39.105322       -76.846451           Café
# 374  more than java cafe'       39.105322       -76.846451           Café
# 474  more than java cafe'       39.105322       -76.846451           Café
# 840  more than java cafe'       39.105322       -76.846451           Café

# %%
aa_coffee_shops.dtypes
# Out:
# Neighborhood               object
# Neighborhood Latitude     float64
# Neighborhood Longitude    float64
# Venue                      object
# Venue Latitude            float64
# Venue Longitude           float64
# Venue Category             object
# Clus_Db                     int64
# dtype: object

# %%
# set number of clusters
kclusters = 7

coffe_shop_clustering = aa_coffee_shops[['Venue Latitude', 'Venue Longitude']]

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(coffe_shop_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([5, 5, 5, 5, 5, 5, 6, 5, 5, 0])

# %% [markdown]
# Create a new dataframe that includes the cluster:

# %%
# add clustering labels
aa_coffee_shops.insert(0, 'Cluster Labels', kmeans.labels_)

# %%
aa_coffee_shops.head()
# Out:
#      Cluster Labels        Neighborhood  Neighborhood Latitude  \
# 36                5  Annapolis Junction              39.125563
# 136               5          Fort Meade              39.125563
# 374               5              Laurel              39.101077
# 474               5          Fort Meade              39.101077
# 840               5          Fort Meade              39.107783
#
#      Neighborhood Longitude                 Venue  Venue Latitude  \
# 36               -76.785436  more than java cafe'       39.105322
# 136              -76.785436  more than java cafe'       39.105322
# 374              -76.804003  more than java cafe'       39.105322
# 474              -76.804003  more than java cafe'       39.105322
# 840              -76.747196  more than java cafe'       39.105322
#
#      Venue Longitude Venue Category  Clus_Db
# 36        -76.846451           Café        0
# 136       -76.846451           Café        0
# 374       -76.846451           Café        0
# 474       -76.846451           Café        0
# 840       -76.846451           Café        0

# %% [markdown]
# Map the resulting clusters:

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(aa_coffee_shops['Venue Latitude'], aa_coffee_shops['Venue Longitude'], aa_coffee_shops['Neighborhood'], aa_coffee_shops['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Now, I'm going to use the DBSCAN clustering method to see how this changes the clustering results:

# %%
from sklearn.cluster import DBSCAN
import sklearn.utils
from sklearn.preprocessing import StandardScaler
sklearn.utils.check_random_state(1000)
from sklearn.cluster import DBSCAN 
from sklearn.datasets.samples_generator import make_blobs 
from sklearn.preprocessing import StandardScaler 
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
Clus_dataSet = aa_coffee_shops[['Venue Latitude','Venue Longitude']]
Clus_dataSet = np.nan_to_num(Clus_dataSet)
Clus_dataSet = StandardScaler().fit_transform(Clus_dataSet)

# %%
# Compute DBSCAN
db = DBSCAN(eps=0.15, min_samples=10).fit(Clus_dataSet)
core_samples_mask = np.zeros_like(db.labels_, dtype=bool)
core_samples_mask[db.core_sample_indices_] = True
labels = db.labels_
aa_coffee_shops["Clus_Db"]=labels

realClusterNum=len(set(labels)) - (1 if -1 in labels else 0)
clusterNum = len(set(labels)) 


# A sample of clusters
aa_coffee_shops[["Neighborhood","Clus_Db"]].head()
# Out:
#            Neighborhood  Clus_Db
# 36   Annapolis Junction        0
# 136          Fort Meade        0
# 374              Laurel        0
# 474          Fort Meade        0
# 840          Fort Meade        0

# %%
aa_coffee_shops.describe()
# Out:
#        Cluster Labels  Neighborhood Latitude  Neighborhood Longitude  \
# count      184.000000             184.000000              184.000000
# mean         2.211957              39.035506              -76.612653
# std          2.163702               0.109822                0.114995
# min          0.000000              38.689075              -76.804003
# 25%          0.000000              38.986634              -76.716408
# 50%          1.000000              39.028343              -76.579016
# 75%          4.000000              39.120916              -76.531506
# max          6.000000              39.226117              -76.428558
#
#        Venue Latitude  Venue Longitude     Clus_Db
# count      184.000000       184.000000  184.000000
# mean        39.039704       -76.615762    1.141304
# std          0.113999         0.117816    1.905308
# min         38.716557       -76.846451   -1.000000
# 25%         38.978219       -76.725399   -1.000000
# 50%         39.038072       -76.598151    1.000000
# 75%         39.137830       -76.503006    3.000000
# max         39.280709       -76.424510    5.000000

# %%
aa_coffee_shops.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 184 entries, 36 to 4462
# Data columns (total 9 columns):
# Cluster Labels            184 non-null int32
# Neighborhood              184 non-null object
# Neighborhood Latitude     184 non-null float64
# Neighborhood Longitude    184 non-null float64
# Venue                     184 non-null object
# Venue Latitude            184 non-null float64
# Venue Longitude           184 non-null float64
# Venue Category            184 non-null object
# Clus_Db                   184 non-null int64
# dtypes: float64(4), int32(1), int64(1), object(3)
# memory usage: 13.7+ KB

# %% [markdown]
# Map the resulting clusters:

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(aa_coffee_shops['Venue Latitude'], aa_coffee_shops['Venue Longitude'], aa_coffee_shops['Neighborhood'], aa_coffee_shops['Clus_Db']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ***
